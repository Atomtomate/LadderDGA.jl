# %%
ENV["GKS_ENCODING"] = "utf-8"
include("src/ladderDGA_Julia.jl");
# Out:
# Inputs Read. Starting Computation
# Calculating bubble:   0.903193 seconds (1.12 M allocations: 61.424 MiB, 2.42% gc time)
# Calculating χ and γ in the charge channel:  47.121127 seconds (76.58 M allocations: 27.303 GiB, 15.47% gc time)
#
#
# -----------
#
# 1 0.000000 0.000000 -0.023412 -0.047225
# 2 0.000000 0.000000 0.002630 0.018630
# 3 0.000000 0.000000 0.000263 0.040768
# 4 0.000000 0.000000 -0.010033 0.051895
# 5 0.000000 0.000000 -0.006919 0.088675
# 6 0.000000 0.000000 -0.007611 0.115774
# 7 0.000000 0.000000 -0.001049 0.104535
# 8 0.000000 0.000000 -0.000470 0.095070
# 9 0.000000 0.000000 -0.000311 0.088851
# 10 0.000000 0.000000 -0.000219 0.084285
# 1 0.064114 0.000000 -0.020320 -0.046942
# 2 0.064114 0.000000 0.002616 0.018618
# 3 0.064114 0.000000 0.000125 0.041008
# 4 0.064114 0.000000 -0.009063 0.052070
# 5 0.064114 0.000000 -0.006848 0.088568
# 6 0.064114 0.000000 -0.007379 0.116087
# 7 0.064114 0.000000 -0.001014 0.104530
# 8 0.064114 0.000000 -0.000452 0.095076
# 9 0.064114 0.000000 -0.000299 0.088856
# 10 0.064114 0.000000 -0.000211 0.084289
# 1 0.128228 0.000000 -0.012497 -0.044684
# 2 0.128228 0.000000 0.002480 0.018671
# 3 0.128228 0.000000 0.000008 0.041710
# 4 0.128228 0.000000 -0.006919 0.052720
# 5 0.128228 0.000000 -0.006597 0.088170
# 6 0.128228 0.000000 -0.006686 0.116909
# 7 0.128228 0.000000 -0.000913 0.104516
# 8 0.128228 0.000000 -0.000403 0.095090
# 9 0.128228 0.000000 -0.000267 0.088869
# 10 0.128228 0.000000 -0.000188 0.084299
# 1 0.192342 0.000000 -0.004383 -0.039120
# 2 0.192342 0.000000 0.002062 0.018978
# 3 0.192342 0.000000 0.000287 0.042617
# 4 0.192342 0.000000 -0.004779 0.053626
# 5 0.192342 0.000000 -0.006034 0.087349
# 6 0.192342 0.000000 -0.005602 0.117978
# 7 0.192342 0.000000 -0.000764 0.104495
# 8 0.192342 0.000000 -0.000334 0.095106
# 9 0.192342 0.000000 -0.000220 0.088884
# 10 0.192342 0.000000 -0.000156 0.084310
# 1 0.256457 0.000000 -0.000031 -0.032803
# 2 0.256457 0.000000 0.001393 0.019660
# 3 0.256457 0.000000 0.000734 0.043344
# 4 0.256457 0.000000 -0.003087 0.054284
# 5 0.256457 0.000000 -0.005017 0.086153
# 6 0.256457 0.000000 -0.004287 0.119072
# 7 0.256457 0.000000 -0.000590 0.104463
# 8 0.256457 0.000000 -0.000256 0.095115
# 9 0.256457 0.000000 -0.000168 0.088894
# 10 0.256457 0.000000 -0.000119 0.084318
# 1 0.320571 0.000000 0.000582 -0.029384
# 2 0.320571 0.000000 0.000731 0.020665
# 3 0.320571 0.000000 0.000889 0.043881
# 4 0.320571 0.000000 -0.001866 0.054338
#  [2] top-level scope at /home/julian/Hamburg/ladderDGA_Julia/src/ladderDGA_Julia.jl:108
#  [3] include at ./boot.jl:328 [inlined]
#  [4] include_relative(::Module, ::String) at ./loading.jl:1094
#  [5] include(::Module, ::String) at ./Base.jl:31
#  [6] include(::String) at ./client.jl:431
#  [7] top-level scope at In[12]:2

# %%
include("src/GFFit.jl")
start = 30
sum_bubble, tail_bubble = fit_F_sum(bubble, start, modelParams, simParams, 2);
limit = approx_full_sum(bubble, start, modelParams, simParams, 2);
n_iν = size(bubble,2)
x = iν_array(modelParams.β, n_iν)[start:end]
fitted_bubble1 = real(tail_func_cmplx(x, tail_bubble[1,1,:]));
fitted_bubble2 = real(tail_func_cmplx(x, tail_bubble[6,1,:]));
fitted_bubble3 = real(tail_func_cmplx(x, tail_bubble[6,end,:]));
f1 = Plots.plot(start:n_iν, real(sum_bubble[1,1,:]), title="iωₙ=-6, q=0", ylabel="bubble(iνₙ_max)", xlabel="iνₙ_max")
f1 = Plots.plot!(start:n_iν, fitted_bubble1)
f1 = Plots.plot!(start:n_iν, repeat([tail_bubble[1,1,1]], length(start:n_iν)))
f1 = Plots.plot!(start:n_iν, repeat([real(limit[1,1,1])], length(start:n_iν)))
f2 = Plots.plot(start:n_iν, real(sum_bubble[6,1,:]), title="iωₙ=0, q=0", ylabel="bubble(iνₙ_max)", xlabel="iνₙ_max")
f2 = Plots.plot!(start:n_iν, fitted_bubble2)
f2 = Plots.plot!(start:n_iν, repeat([tail_bubble[6,1,1]], length(start:n_iν)))
f3 = Plots.plot(start:n_iν, real(sum_bubble[6,end,:]), title="iωₙ=0, q=π", ylabel="bubble(iνₙ_max)", xlabel="iνₙ_max")
f3 = Plots.plot!(start:n_iν, fitted_bubble3)
f3 = Plots.plot!(start:n_iν, repeat([tail_bubble[6,end,1]], length(start:n_iν)))
f4 = Plots.plot(start:n_iν, real(sum_bubble[end,end,:]), title="iωₙ=6, q=π", ylabel="bubble(iνₙ_max)", xlabel="iνₙ_max")
f4 = Plots.plot!(start:n_iν, real(tail_func_full(x, tail_bubble[end,end,:])))
f4 = Plots.plot!(start:n_iν, repeat([tail_bubble[end,end,1]], length(start:n_iν)))
f = plot(f1,f2,f3,f4,layout=(2,2),legend=:none)
display(f)
# Out:
# (13, 36, 1)
# -0.1890021004918412
# -0.1890021004918412

# %%
start = 38
sum_bubble, tail_bubble = fit_F_sum(bubble, start, modelParams, simParams, 2);
limit = approx_full_sum(bubble, start, modelParams, simParams, 2);
n_iν = size(bubble,2)
x = iν_array(modelParams.β, n_iν)[start:end]
fitted_bubble1 = real(tail_func_cmplx(x, tail_bubble[1,1,:]));
fitted_bubble2 = real(tail_func_cmplx(x, tail_bubble[6,1,:]));
fitted_bubble3 = real(tail_func_cmplx(x, tail_bubble[6,end,:]));
f1 = Plots.plot(start:n_iν, real(sum_bubble[1,1,:]), title="iωₙ=-6, q=0", ylabel="bubble(iνₙ_max)", xlabel="iνₙ_max")
f1 = Plots.plot!(start:n_iν, fitted_bubble1)
f1 = Plots.plot!(start:n_iν, repeat([tail_bubble[1,1,1]], length(start:n_iν)))
f1 = Plots.plot!(start:n_iν, repeat([real(limit[1,1,1])], length(start:n_iν)))
f2 = Plots.plot(start:n_iν, real(sum_bubble[6,1,:]), title="iωₙ=0, q=0", ylabel="bubble(iνₙ_max)", xlabel="iνₙ_max")
f2 = Plots.plot!(start:n_iν, fitted_bubble2)
f2 = Plots.plot!(start:n_iν, repeat([tail_bubble[6,1,1]], length(start:n_iν)))
f3 = Plots.plot(start:n_iν, real(sum_bubble[6,end,:]), title="iωₙ=0, q=π", ylabel="bubble(iνₙ_max)", xlabel="iνₙ_max")
f3 = Plots.plot!(start:n_iν, fitted_bubble3)
f3 = Plots.plot!(start:n_iν, repeat([tail_bubble[6,end,1]], length(start:n_iν)))
f4 = Plots.plot(start:n_iν, real(sum_bubble[end,end,:]), title="iωₙ=6, q=π", ylabel="bubble(iνₙ_max)", xlabel="iνₙ_max")
f4 = Plots.plot!(start:n_iν, real(tail_func_full(x, tail_bubble[end,end,:])))
f4 = Plots.plot!(start:n_iν, repeat([tail_bubble[end,end,1]], length(start:n_iν)))
f = plot(f1,f2,f3,f4,layout=(2,2),legend=:none)
display(f)

# %%
size(bubble)
# Out:
# (13, 50, 36)

# %%
start = 42
limit = zeros((size(bubble,1),size(bubble,3),size(bubble,2)-1))
limit2 = zeros((size(bubble,1),size(bubble,3),size(bubble,2)-1))
for start in 1:49
    limit[:,:,start] = real.(approx_full_sum(bubble, start, modelParams, simParams, 2, tail_func_cmplx, 6));
    limit2[:,:,start] = approx_full_sum(bubble, start, modelParams, simParams, 2, tail_func_full, 3);
end
print(size(real(limit[1,1,:])))
f1 = Plots.plot(1:size(bubble,2)-1, real.(limit[1,1,:]), title="iωₙ=-6, q=0", ylabel="Σₙ bubble(q,iωₙ,iνₙ)", xlabel="start", label="complex coeffs")
f1 = Plots.plot!(1:size(bubble,2)-1, real.(limit2[1,1,:]), label="real coeffs")
f2 = Plots.plot(1:size(bubble,2)-1, real.(limit[6,1,:]), title="iωₙ=0, q=0", ylabel="Σₙ bubble(q,iωₙ,iνₙ)", xlabel="start", label="complex coeffs")
f2 = Plots.plot!(1:size(bubble,2)-1, real.(limit2[6,1,:]), label="real coeffs")
f3 = Plots.plot(1:size(bubble,2)-1, real.(limit[6,end,:]), title="iωₙ=0, q=π", ylabel="Σₙ bubble(q,iωₙ,iνₙ)", xlabel="start", label="complex coeffs")
f3 = Plots.plot!(1:size(bubble,2)-1, real.(limit2[6,end,:]), label="real coeffs")
f4 = Plots.plot(1:size(bubble,2)-1, real.(limit[end,end,:]), title="iωₙ=6, q=π", ylabel="Σₙ bubble(q,iωₙ,iνₙ)", xlabel="start", label="complex coeffs")
f4 = Plots.plot!(1:size(bubble,2)-1, real.(limit2[end,end,:]), label="real coeffs")
f = plot(f1,f2,f3,f4,layout=(2,2))
display(f)
# Out:
# (49,)

# %%
l = @layout [a{0.6w} b]
wbox = Int((size(tail_bubble,1)-1)/2)
plot((-wbox):wbox, 1:size(tail_bubble,2), (x,y) -> tail_bubble[x+wbox+1,y,1], st = [:surface, :contourf], layout=l, xlabel="w", ylabel="q", size=(900,400))

# %%
include("src/GFFit.jl")
start = 85
arr_ch = χDMFTch[:,1:end,1:end]
arr_sp = χDMFTsp[:,1:end,1:end]

sum_χch, tail_χch = fit_F_sum(arr_ch, start, modelParams, simParams, [2,3], tail_func_cmplx,10);
sum_χch2, tail_χch2 = fit_F_sum(arr_ch, start, modelParams, simParams, [2,3], tail_func_full,10);
sum_χsp, tail_χsp = fit_F_sum(arr_sp, start, modelParams, simParams, [2,3], tail_func_cmplx,10);
n_iν2 = size(arr_ch,2)
x = iν_array(modelParams.β, n_iν2)[start:end];#χDMFTch

# %%
arr_ch_new = zeros(Complex{Float64}, 13,113,113);
for w in 1:size(arr_ch,1)
    arr_ch_new[w, collect(1:100), collect(1:100)] = arr_ch[w,:,:]
end
#.+ (Int(floor(w/2)))
#.+ (Int(floor(w/2)))
w = 6
Plots.plot(collect(1:113),real.(sum(arr_ch_new[w+7,:,:],dims=[2,3])[:,1,1]), label="iωₙ=6", ylabel="χDMFTch(iνₙ_max)", xlabel="iνₙ_max")
w = 5
Plots.plot!(collect(1:113),real.(sum(arr_ch_new[w+7,:,:],dims=[2,3])[:,1,1]), label="iωₙ=5", ylabel="χDMFTch(iνₙ_max)", xlabel="iνₙ_max")
w = 0
Plots.plot!(collect(1:113),real.(sum(arr_ch_new[w+7,:,:],dims=[2,3])[:,1,1]), label="iωₙ=0", ylabel="χDMFTch(iνₙ_max)", xlabel="iνₙ_max")
w = -5
Plots.plot!(collect(1:113),real.(sum(arr_ch_new[w+7,:,:],dims=[2,3])[:,1,1]), label="iωₙ=-5", ylabel="χDMFTch(iνₙ_max)", xlabel="iνₙ_max")
w = -6
Plots.plot!(collect(1:113),real.(sum(arr_ch_new[w+7,:,:],dims=[2,3])[:,1,1]), label="iωₙ=-6", ylabel="χDMFTch(iνₙ_max)", xlabel="iνₙ_max")

# %%
w = 6
Plots.plot(collect(1:100) .+ w/2,real.(sum(arr_ch[w+7,1:end,:],dims=[2,3])[:,1,1]), label="iωₙ=-6", ylabel="χDMFTch(iνₙ_max)", xlabel="iνₙ_max")
w = 5
Plots.plot!(collect(1:100) .+ w/2,real.(sum(arr_ch[w+7,1:end,:],dims=[2,3])[:,1,1]), label="iωₙ=6", ylabel="χDMFTch(iνₙ_max)", xlabel="iνₙ_max")
w = 0
Plots.plot!(collect(1:100) .+ w/2,real.(sum(arr_ch[w+7,1:end,:],dims=[2,3])[:,1,1]), label="iωₙ=0", ylabel="χDMFTch(iνₙ_max)", xlabel="iνₙ_max")
w = -5
Plots.plot!(collect(1:100) .+ w/2,real.(sum(arr_ch[w+7,1:end,:],dims=[2,3])[:,1,1]), label="iωₙ=6", ylabel="χDMFTch(iνₙ_max)", xlabel="iνₙ_max")
w = -6
Plots.plot!(collect(1:100) .+ w/2,real.(sum(arr_ch[w+7,1:end,:],dims=[2,3])[:,1,1]), label="iωₙ=6", ylabel="χDMFTch(iνₙ_max)", xlabel="iνₙ_max")

# %%
f21 = Plots.plot(start:n_iν2, real(sum_χch[1,:]), title="iωₙ=-6", ylabel="χDMFTch(iνₙ_max)", xlabel="iνₙ_max", label="data")
f21 = Plots.plot!(start:n_iν2, real(tail_func_cmplx(x, tail_χch[1,:])), label="complex fit")
f21 = Plots.plot!(start:n_iν2, real(tail_func_full(x, tail_χch2[1,:])), label="real fit")
f21 = Plots.plot!(start:n_iν2, repeat([tail_χch[1,1]], length(start:n_iν2)), label="limit complex")
f21 = Plots.plot!(start:n_iν2, repeat([tail_χch2[1,1]], length(start:n_iν2)), label="limit real")
f22 = Plots.plot(start:n_iν2, real(sum_χch[6,:]), title="iωₙ=0", ylabel="χDMFTch(iνₙ_max)", xlabel="iνₙ_max")
f22 = Plots.plot!(start:n_iν2, real(tail_func_cmplx(x, tail_χch[6,:])))
f22 = Plots.plot!(start:n_iν2, repeat([tail_χch[6,1]], length(start:n_iν2)))
f23 = Plots.plot(start:n_iν2, real(sum_χch[9,:]), title="iωₙ=3", ylabel="χDMFTch(iνₙ_max)", xlabel="iiνₙ_max")
f23 = Plots.plot!(start:n_iν2, real(tail_func_cmplx(x, tail_χch[9,:])))
f23 = Plots.plot!(start:n_iν2, repeat([tail_χch[9,1]], length(start:n_iν2)))
f24 = Plots.plot(start:n_iν2, real(sum_χch[12,:]), title="iωₙ=6", ylabel="χDMFTch(iνₙ_max)", xlabel="iνₙ_max", label="data")
f24 = Plots.plot!(start:n_iν2, real(tail_func_cmplx(x, tail_χch[12,:])), label="complex fit")
f24 = Plots.plot!(start:n_iν2, real(tail_func_full(x, tail_χch2[12,:])), label="real fit")
f24 = Plots.plot!(start:n_iν2, repeat([tail_χch[12,1]], length(start:n_iν2)), label="limit complex")
f24 = Plots.plot!(start:n_iν2, repeat([tail_χch2[12,1]], length(start:n_iν2)), label="limit real")
f = plot(f21,f24,layout=(2,1), size=(900,600))
display(f)

# %%
χDMFTch_sum = sum(χDMFTch[:,:,:]; dims=[2,3])[:,1,1]
χDMFTsp_sum = sum(χDMFTsp[:,:,:]; dims=[2,3])[:,1,1]
f1 = plot((-wbox):wbox, real(χDMFTch_sum)/(modelParams.β^2), xlabel="w", ylabel="sum", label="naive", title="χDMFTch")
plot!((-wbox):wbox, tail_χch2[:,1], xlabel="w", label="a₀ real coeffs")
plot!((-wbox):wbox, tail_χch[:,1], xlabel="w", label="a₀ complx coeffs")
f2 = plot((-wbox):wbox, real(χDMFTsp_sum)/(modelParams.β^2), xlabel="w", ylabel="sum", label="naive", title="χDMFTsp")
plot!((-wbox):wbox, tail_χsp[:,1], xlabel="w", label="a₀")
f = plot(f1,f2,layout=(1,2), size=(900,400))
display(f)

# %%
start = 70
arr = -χch[:,1:end]

sum_χ, tail_χch = fit_F_sum(arr, start, modelParams, simParams, [2,3]);
n_iν2 = size(arr,2)
x = iν_array(modelParams.β, n_iν2)[start:end];#χDMFTch
# Out:
# BoundsError: attempt to access (13, 36)
#   at index [3]
#
# Stacktrace:
#  [1] getindex at ./tuple.jl:24 [inlined]
#  [2] #26 at ./none:0 [inlined]
#  [3] iterate at ./generator.jl:47 [inlined]
#  [4] collect_to! at ./array.jl:651 [inlined]
#  [5] collect_to_with_first! at ./array.jl:630 [inlined]
#  [6] collect(::Base.Generator{Array{Int64,1},getfield(Base, Symbol("##26#27")){Tuple{Int64,Int64}}}) at ./array.jl:611
#  [7] getindex at ./tuple.jl:26 [inlined]
#  [8] fit_F_sum(::Array{Complex{Float64},2}, ::Int64, ::ModelParameters, ::SimulationParameters, ::Array{Int64,1}, ::Function, ::Int64) at /home/julian/Hamburg/ladderDGA_Julia/src/GFFit.jl:33 (repeats 2 times)
#  [9] top-level scope at In[37]:3
