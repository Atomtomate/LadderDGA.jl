# %%
include("src/ladderDGA_Julia.jl")
# Out:
# Reading Inputs...Reading Fortran Input, this can take several minutes.
# Done Reading Gamma
# Done Reading chi
# TODO: check beta consistency, config <-> g0man, chi_dir <-> gamma dir
# (81, 82, 82)
# Inputs Read. Starting Computation.
# Found usable intervals for local susceptibility of length
#       sp: 15
#       ch: 13
#       χLoc_sp = 0.3557, χLoc_ch = 0.0177
# Setting up and calculating k Grid:
# Calculating bubble:
#   0.679971 seconds (992.06 k allocations: 90.442 MiB, 23.89% gc time)
# Calculating χ and γ:
#  14.591180 seconds (669.34 k allocations: 1.353 GiB, 3.53% gc time)
#   1.064531 seconds (30.70 k allocations: 318.594 MiB, 2.04% gc time)
# Found usable intervals for non-local susceptibility of length
#       sp: 33:49, length: 17
#       ch: 34:48, length: 15
#       usable: 34:48, length: 15
# Using rhs for non tail corrected lambda correction:
#       0.3572 = 0.0177 + 0.3557 - 0.0162
# Calculating λ correction in the spin channel:
# ...

# %%
ENV["GKS_ENCODING"] = "utf-8"
using Plots

# %%
plot(real(Σ_ladder[:,1]), label="Re[Σ(q=(0,0,0))]", title="Σ usable")
plot!(real(Σ_ladder[:,end]), label="Re[Σ(q=(π,π,π))]")

# %%
plot(imag(Σ_ladder[:,1]), label="Im[Σ(q=(0,0,0))]", title="Σ usable")
plot!(imag(Σ_ladder[:,end]), label="Im[Σ(q=(π,π,π))]")

# %%
plot(real(Σ_ladder_f[:,1]), label="Re[Σ(q=(0,0,0))]", title="Σ full")
plot!(real(Σ_ladder_f[:,end]), label="Re[Σ(q=(π,π,π))]", title="Σ full")

# %%
plot(imag(Σ_ladder_f[:,1]), label="Im[Σ(q=(0,0,0))]", title="Σ full")
plot!(imag(Σ_ladder_f[:,end]), label="Im[Σ(q=(π,π,π))]", title="Σ full")

# %%
collect(kGrid)[:]
# Out:
# 216-element Array{Tuple{Float64,Float64,Float64},1}:
#  (-2.0943951023931957, -2.0943951023931957, -2.0943951023931957)
#  (-1.0471975511965979, -2.0943951023931957, -2.0943951023931957)
#  (0.0, -2.0943951023931957, -2.0943951023931957)
#  (1.0471975511965974, -2.0943951023931957, -2.0943951023931957)
#  (2.094395102393195, -2.0943951023931957, -2.0943951023931957)
#  (3.141592653589793, -2.0943951023931957, -2.0943951023931957)
#  (-2.0943951023931957, -1.0471975511965979, -2.0943951023931957)
#  (-1.0471975511965979, -1.0471975511965979, -2.0943951023931957)
#  (0.0, -1.0471975511965979, -2.0943951023931957)
#  (1.0471975511965974, -1.0471975511965979, -2.0943951023931957)
#  (2.094395102393195, -1.0471975511965979, -2.0943951023931957)
#  (3.141592653589793, -1.0471975511965979, -2.0943951023931957)
#  (-2.0943951023931957, 0.0, -2.0943951023931957)
#  ⋮
#  (-2.0943951023931957, 2.094395102393195, 3.141592653589793)
#  (-1.0471975511965979, 2.094395102393195, 3.141592653589793)
# ...

# %%
collect(ϵkGrid)[:]
# Out:
# 216-element Array{Float64,1}:
#   0.6123724356957948
#   0.20412414523193173
#   1.8129866073473578e-16
#   0.20412414523193156
#   0.6123724356957945
#   0.8164965809277263
#   0.20412414523193173
#  -0.20412414523193131
#  -0.4082482904638629
#  -0.2041241452319315
#   0.20412414523193143
#   0.4082482904638632
#   1.8129866073473578e-16
#   ⋮
#   0.8164965809277258
#   0.40824829046386285
#   0.2041241452319313
#   0.40824829046386263
#   0.8164965809277256
#   1.0206207261596574
#   1.0206207261596576
#   0.6123724356957945
#   0.408248290463863
#   0.6123724356957944
#   1.0206207261596574
#   1.224744871391589

# %%
Σ_ladder_f[:,1]
# Out:
# 41-element Array{Complex{Float64},1}:
#    -0.5988846560932999 - 1.2069507378026847im
#    -0.6121989112564148 + 0.05546045505991953im
#    -0.4933755231971289 - 2.3193970986881918im
#   -0.44112822965551385 - 1.2827451130978704im
#   -0.36168665429086155 - 1.016689932741424im
#    -0.3003157099644066 - 0.9138666050692854im
#    -0.2517551713076745 - 0.8609161377530117im
#    -0.2131023995597535 - 0.8333493009342029im
#   -0.18208969434211175 - 0.8217374568779056im
#   -0.15698567095576738 - 0.8214168578501416im
#   -0.13648299421523777 - 0.82971280624101im
#   -0.11959402523743835 - 0.8449242950810298im
#   -0.10556857864775177 - 0.8658820904009366im
#                        ⋮
#   -0.02851872970320359 - 1.6729402491314151im
#  -0.027361418967193227 - 1.736064931255373im
#  -0.026326180858421533 - 1.8003344482103874im
#   -0.02539737061545994 - 1.865663825547717im
#   -0.02455926199170729 - 1.9319645579370879im
#  -0.023791448695878934 - 1.999246160725893im
# ...

# %%
Σ_ladder_f[:,1]
# Out:
# 41-element Array{Complex{Float64},1}:
#    -0.5988846560932999 - 1.2069507378026847im
#    -0.6121989112564148 + 0.05546045505991953im
#    -0.4933755231971289 - 2.3193970986881918im
#   -0.44112822965551385 - 1.2827451130978704im
#   -0.36168665429086155 - 1.016689932741424im
#    -0.3003157099644066 - 0.9138666050692854im
#    -0.2517551713076745 - 0.8609161377530117im
#    -0.2131023995597535 - 0.8333493009342029im
#   -0.18208969434211175 - 0.8217374568779056im
#   -0.15698567095576738 - 0.8214168578501416im
#   -0.13648299421523777 - 0.82971280624101im
#   -0.11959402523743835 - 0.8449242950810298im
#   -0.10556857864775177 - 0.8658820904009366im
#                        ⋮
#   -0.02851872970320359 - 1.6729402491314151im
#  -0.027361418967193227 - 1.736064931255373im
#  -0.026326180858421533 - 1.8003344482103874im
#   -0.02539737061545994 - 1.865663825547717im
#   -0.02455926199170729 - 1.9319645579370879im
#  -0.023791448695878934 - 1.999246160725893im
# ...

# %%
Σ_ladder[:,1]
# Out:
# 41-element Array{Complex{Float64},1}:
#    -0.6488516548705684 - 0.7454397323756622im
#    -0.5883082887874641 - 0.8752965300445579im
#    -0.5157110521662885 - 0.8687625569772265im
#    -0.4318016628878355 - 0.812875453298289im
#    -0.3574803175416134 - 0.7546467601299911im
#   -0.29664468153079515 - 0.7093696442259373im
#   -0.24730750033690374 - 0.6802200474470672im
#    -0.2077171149517731 - 0.5638836773669755im
#   -0.17629334807706695 - 0.5123911704450667im
#   -0.15125482216907096 - 0.47439459449676247im
#    -0.1309207871429313 - 0.4444745765822138im
#   -0.11423177115018901 - 0.4188312727283092im
#   -0.10040543813862031 - 0.3959369307673706im
#                        ⋮
#   -0.02255599880566324 - 0.19609598211660278im
#  -0.021196498739937914 - 0.1902125283185958im
#   -0.01995505282790985 - 0.18466258009790273im
#   -0.01881850814627762 - 0.17941955323789724im
#   -0.01777547607411797 - 0.17445947255907696im
#  -0.016816060948109824 - 0.1697606223946244im
# ...

# %%
Σ_ladder_naive[1,:]
# Out:
# 20-element Array{Complex{Float64},1}:
#  NaN + NaN*im
#  NaN + NaN*im
#  NaN + NaN*im
#  NaN + NaN*im
#  NaN + NaN*im
#  NaN + NaN*im
#  NaN + NaN*im
#  NaN + NaN*im
#  NaN + NaN*im
#  NaN + NaN*im
#  NaN + NaN*im
#  NaN + NaN*im
#  NaN + NaN*im
#  NaN + NaN*im
#  NaN + NaN*im
#  NaN + NaN*im
#  NaN + NaN*im
#  NaN + NaN*im
#  NaN + NaN*im
#  NaN + NaN*im

# %%
Σ_ladder_naive_f[1,:]
# Out:
# 20-element Array{Complex{Float64},1}:
#      0.5988846560933723 - 1.2069507378026885im
#      0.5809524636797927 - 1.303057768177142im
#      0.5403646539494574 - 1.4121293508445594im
#     0.46686456811923993 - 1.5285813814494762im
#     0.47080701146171844 - 1.5333492705986336im
#     0.35308244763559193 - 1.6444310080558737im
#      0.1914443647520094 - 1.726483048588732im
#  -0.0012743569249774294 - 1.761346305337139im
#     -0.1914444100474751 - 1.726483043368447im
#     -0.4668646081094414 - 1.5285813687345906im
#     0.35707380814580564 - 1.6492238171344082im
#      0.1935702144387054 - 1.7319635980919703im
#   0.0012743107051103458 - 1.7613463053777587im
#    -0.19357025986078855 - 1.7319635928048713im
#     -0.3530824907207479 - 1.6444309984292633im
#      -0.540364690813268 - 1.4121293361292664im
#     -0.3570738513401934 - 1.6492238073827137im
#     -0.4708070515606606 - 1.5333492577610872im
#      -0.580952497622485 - 1.3030577523579536im
# ...
